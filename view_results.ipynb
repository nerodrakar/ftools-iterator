# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('resultados_variavel_50_xm.xlsx')
df
# Out:
#              P        m1        m2
# 0   427.978206  3374.105  -803.177
# 1   456.350324  3010.388  -681.174
# 2   376.277468  2937.464  -679.570
# 3   408.574194  3205.226  -746.950
# 4   387.044639  3921.591  -907.098
# 5   369.179873  3019.653  -668.325
# 6   312.922736  3485.010  -800.760
# 7   392.256136  3680.075  -864.307
# 8   380.787262  3995.136  -939.732
# 9   530.871523  3411.079  -779.297
# 10  382.396549  3053.366  -722.427
# 11  410.730922  3290.369  -736.924
# 12  533.468136  3302.031  -753.702
# 13  430.336789  3472.779  -818.350
# 14  674.662900  3874.800  -897.389
# 15  438.009273  3531.565  -814.419
# 16  688.437927  3628.003  -802.160
# 17  492.217576  3570.881  -815.899
# 18  445.980977  4237.553  -989.367
# 19  482.928947  3801.930  -900.956
# 20  325.980971  3125.726  -722.312
# 21  374.347675  5390.704 -1291.607
# 22  446.876100  2962.411  -685.606
# 23  621.442087  3835.514  -901.747
# 24  388.286691  3850.456  -875.916
# 25  307.355801  3902.123  -888.718
# 26  471.102351  3606.270  -849.633
# 27  398.192932  2873.417  -665.151
# 28  366.886140  3050.101  -701.407
# 29  421.855421  4139.028  -978.626
# 30  683.841982  6702.290 -1612.015
# 31  493.539720  3067.660  -695.314
# 32  350.047144  3681.090  -794.549
# 33  474.845540  3948.737  -920.131
# 34  581.679659  3066.572  -719.040
# 35  484.525205  3374.393  -766.361
# 36  377.586412  3915.663  -909.831
# 37  555.015889  3062.401  -699.165
# 38  384.831908  3540.577  -803.572
# 39  439.653897  4434.427 -1050.022
# 40  338.812159  3366.851  -748.418
# 41  392.310338  4163.534  -959.072
# 42  395.174986  3126.082  -727.221
# 43  394.856835  3594.550  -819.454
# 44  433.615526  3020.470  -692.724
# 45  411.816661  3366.948  -790.314
# 46  424.000902  4254.943  -993.772
# 47  454.742636  3511.724  -816.156
# 48  415.767495  3376.009  -792.959
# 49  424.010216  3185.493  -727.229

# %%
plt.hist(df['m2'])
# Out:
# (array([ 1.,  0.,  0.,  1.,  0.,  1.,  4., 10., 15., 18.]),
#  array([-1612.015 , -1517.3286, -1422.6422, -1327.9558, -1233.2694,
#         -1138.583 , -1043.8966,  -949.2102,  -854.5238,  -759.8374,
#          -665.151 ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Gerando dados
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Criando a figura e o gráfico
plt.figure(figsize=(8, 5))
plt.plot(x, y, label="Seno(x)", color="b")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Gráfico de Seno")
plt.legend()

# Defina o caminho onde deseja salvar a imagem
caminho = "./grafico.png"  # Altere conforme necessário

# Salvando a imagem
plt.savefig(caminho, dpi=300, bbox_inches='tight')

# Mostrando a imagem
plt.show()
# Fechando a figura
plt.close()

print(f"Imagem salva em: {caminho}")
# Out:
# Imagem salva em: ./grafico.png
